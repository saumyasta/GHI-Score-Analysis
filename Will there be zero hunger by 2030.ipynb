# %%
# data analysis and wrangling

import numpy as np 
import pandas as pd 
from pandas import Series,DataFrame

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# machine learning

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn import utils

# %%
df_global_hunger_index = pd.read_csv("GHI2022 scores.csv", encoding= 'unicode_escape')
df_child_undernourished = pd.read_csv("Proportion of undernourished in the population.csv", encoding= 'unicode_escape')
df_child_wasting = pd.read_csv("Prevalence of wasting in children under five years.csv", encoding= 'unicode_escape')
df_child_stunting = pd.read_csv("Prevalence of stunting in children under five years.csv", encoding= 'unicode_escape')
df_child_mortality = pd.read_csv("Under-five mortality rate.csv", encoding= 'unicode_escape')

# %% [markdown]
# ### Data Preprocessing

# %%
df_global_hunger_index.head()
# Out:
#        Country  2000  2007  2014  2022  Absolute change since 2014  \
# 0  Afghanistan  50.3  38.7  30.6  29.9                        -0.7
# 1      Albania  20.7  15.8   9.2   6.2                        -3.0
# 2      Algeria  14.5  11.4   8.7   6.9                        -1.8
# 3       Angola  64.9  44.7  26.2  25.9                        -0.3
# 4    Argentina   6.6   5.5   5.0   6.8                         1.8
#
#    % change since 2014
# 0                 -2.3
# 1                -32.6
# 2                -20.7
# 3                 -1.1
# 4                 36.0

# %%
#Dropping unnecessary columns

df_global_hunger_index.drop("Absolute change since 2014", inplace=True, axis=1)
df_global_hunger_index.drop("% change since 2014", inplace=True, axis=1)
df_global_hunger_index
# Out:
#                         Country  2000  2007  2014  2022
# 0                   Afghanistan  50.3  38.7  30.6  29.9
# 1                       Albania  20.7  15.8   9.2   6.2
# 2                       Algeria  14.5  11.4   8.7   6.9
# 3                        Angola  64.9  44.7  26.2  25.9
# 4                     Argentina   6.6   5.5   5.0   6.8
# ..                          ...   ...   ...   ...   ...
# 131  Venezuela (Boliv. Rep. of)  14.6  10.1   8.1  19.9
# 132                    Viet Nam  26.3  21.4  15.4  11.9
# 133                       Yemen  41.3  38.4  41.7  45.1
# 134                      Zambia  53.3  46.0  35.2  29.3
# 135                    Zimbabwe   NaN   NaN   NaN   NaN
#
# [136 rows x 5 columns]

# %%
df_child_undernourished.head()
# Out:
#        Country  2000  2007  2014  2022
# 0  Afghanistan  47.8  29.8  20.7  29.8
# 1      Albania   4.9   8.3   5.0   3.9
# 2      Algeria   8.0   5.9   2.9   2.0
# 3       Angola  67.5  46.1  13.7  20.8
# 4    Argentina   3.0   3.3   2.0   3.7

# %%
df_child_wasting.head()
# Out:
#        Country  2000  2007  2014  2022
# 0  Afghanistan  10.9   8.3   9.5   5.1
# 1      Albania  12.2   8.5   4.5   1.6
# 2      Algeria   3.1   4.1   4.1   2.7
# 3       Angola  11.2   8.2   4.9   6.1
# 4    Argentina   1.7   1.2   1.6   2.7

# %%
df_child_stunting.head()
# Out:
#        Country  2000  2007  2014  2022
# 0  Afghanistan  50.6  51.1  40.4  38.2
# 1      Albania  39.2  25.0  15.2  11.3
# 2      Algeria  23.6  15.4  11.7   9.8
# 3       Angola  46.7  29.2  37.6  29.8
# 4    Argentina  10.5   8.2   8.3  12.3

# %%
df_child_mortality.head()
# Out:
#        Country  2000  2007  2014  2022
# 0  Afghanistan  12.9  10.0   7.4   5.8
# 1      Albania   2.7   1.7   1.0   1.0
# 2      Algeria   4.0   3.1   2.5   2.3
# 3       Angola  20.4  14.7   9.3   7.1
# 4    Argentina   2.0   1.6   1.2   0.9

# %%
#Check Null Values

df_global_hunger_index.isnull().sum()
# Out:
# Country     0
# 2000       19
# 2007       16
# 2014       15
# 2022       15
# dtype: int64

# %%
#Remove null values

df_global_hunger_index.dropna()
# Out:
#                         Country  2000  2007  2014  2022
# 0                   Afghanistan  50.3  38.7  30.6  29.9
# 1                       Albania  20.7  15.8   9.2   6.2
# 2                       Algeria  14.5  11.4   8.7   6.9
# 3                        Angola  64.9  44.7  26.2  25.9
# 4                     Argentina   6.6   5.5   5.0   6.8
# ..                          ...   ...   ...   ...   ...
# 130                  Uzbekistan  24.2  15.4   8.3   5.6
# 131  Venezuela (Boliv. Rep. of)  14.6  10.1   8.1  19.9
# 132                    Viet Nam  26.3  21.4  15.4  11.9
# 133                       Yemen  41.3  38.4  41.7  45.1
# 134                      Zambia  53.3  46.0  35.2  29.3
#
# [117 rows x 5 columns]

# %%
#Check duplicate values

df_global_hunger_index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data analysis

# %%
df_global_hunger_index.describe()
# Out:
#              2000        2007        2014        2022
# count  117.000000  120.000000  121.000000  121.000000
# mean    24.676068   20.401667   16.276860   15.220661
# std     14.934452   12.819451   10.711231   10.307375
# min      3.000000    3.000000    3.000000    3.000000
# 25%     11.600000    8.725000    7.400000    6.800000
# 50%     20.900000   18.000000   13.000000   13.200000
# 75%     37.000000   30.925000   25.500000   21.700000
# max     64.900000   51.100000   44.600000   45.100000

# %%
df_countries = df_global_hunger_index['Country'].unique()
df_countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Belarus',
#        'Benin', 'Bhutan', 'Bolivia (Plurinat. State of)',
#        'Bosnia & Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo (Republic of)', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Dem. Rep. of the Congo', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Fiji', 'Gabon', 'Gambia', 'Georgia', 'Ghana', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hungary', 'India', 'Indonesia', 'Iran (Islamic Republic of)',
#        'Iraq', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Korea (DPR)',
#        'Kuwait', 'Kyrgyzstan', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Lithuania', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Mauritania', 'Mauritius',
#        'Mexico', 'Moldova (Rep. of)', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nicaragua', 'Niger',
#        'Nigeria', 'North Macedonia', 'Oman', 'Pakistan', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Qatar',
#        'Romania', 'Russian Federation', 'Rwanda', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Sierra Leone', 'Slovakia', 'Solomon Islands',
#        'Somalia', 'South Africa', 'South Sudan', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania (United Rep. of)', 'Thailand', 'Timor-Leste', 'Togo',
#        'Trinidad & Tobago', 'Tunisia', 'Türkiye', 'Turkmenistan',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'Uruguay',
#        'Uzbekistan', 'Venezuela (Boliv. Rep. of)', 'Viet Nam', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
df_global_hunger_index.columns
# Out:
# Index(['Country', '2000', '2007', '2014', '2022'], dtype='object')

# %% [markdown]
# ### Data Analysis and visualization

# %%
Countries = df_global_hunger_index["Country"].unique()
Countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Belarus',
#        'Benin', 'Bhutan', 'Bolivia (Plurinat. State of)',
#        'Bosnia & Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo (Republic of)', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Dem. Rep. of the Congo', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Fiji', 'Gabon', 'Gambia', 'Georgia', 'Ghana', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hungary', 'India', 'Indonesia', 'Iran (Islamic Republic of)',
#        'Iraq', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Korea (DPR)',
#        'Kuwait', 'Kyrgyzstan', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Lithuania', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Mauritania', 'Mauritius',
#        'Mexico', 'Moldova (Rep. of)', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nicaragua', 'Niger',
#        'Nigeria', 'North Macedonia', 'Oman', 'Pakistan', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Qatar',
#        'Romania', 'Russian Federation', 'Rwanda', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Sierra Leone', 'Slovakia', 'Solomon Islands',
#        'Somalia', 'South Africa', 'South Sudan', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania (United Rep. of)', 'Thailand', 'Timor-Leste', 'Togo',
#        'Trinidad & Tobago', 'Tunisia', 'Türkiye', 'Turkmenistan',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'Uruguay',
#        'Uzbekistan', 'Venezuela (Boliv. Rep. of)', 'Viet Nam', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
Number_countries = df_global_hunger_index["Country"].unique().size
Number_countries
# Out:
# 136

# %%
sns.pairplot(df_global_hunger_index)

# %%
col=["2000","2007","2014","2022"]
fig = plt.figure(figsize=(15,5))

for i in range(len(col)):
    plt.subplot(1,4,i+1)
    plt.title(col[i])
    sns.distplot(df_global_hunger_index,x=df_global_hunger_index[col[i]])
    plt.xlim([0,75])
    plt.ylim([0,0.06])
plt.tight_layout()
plt.show()

# %%
df_GHI=df_global_hunger_index

# %%
df_GHI[df_GHI["2000"]>=50].sort_values(by="2000",ascending=True).plot.barh(y="2000",x='Country',legend=False);

# %%
df_GHI[df_GHI["2022"]>=35].sort_values(by="2022",ascending=True).plot.barh(y="2022",x='Country',legend=False);

# %%
df_GHI[df_GHI["2022"]>=20].sort_values(by="2022",ascending=True).plot.barh(y="2022",x='Country',legend=False,figsize=(10, 12) );

# %%
((df_GHI["2022"] > 20) & (df_GHI["2022"] < 35)).sum()
# Out:
# 30

# %%
df_GHI[df_GHI["2022"]< 10].sort_values(by="2022",ascending=True).plot.barh(y="2022",x='Country',legend=True, figsize=(10, 12));
#plt.figure(figsize=(12, 50))

# %%
(df_GHI["2022"] < 10).sum()
# Out:
# 49

# %% [markdown]
# Only 49 countries in world are in low category in 2022.

# %%
Low_Countries = df_GHI.where (df_GHI["2022"] < 10)
Low_Countries = Low_Countries.dropna()
Low_Countries
# Out:
#                         Country  2000  2007  2014  2022
# 1                       Albania  20.7  15.8   9.2   6.2
# 2                       Algeria  14.5  11.4   8.7   6.9
# 4                     Argentina   6.6   5.5   5.0   6.8
# 5                       Armenia  19.3  12.1   7.3   6.9
# 6                    Azerbaijan  24.9  15.3   9.3   7.5
# 9                       Belarus   3.0   3.0   3.0   3.0
# 13         Bosnia & Herzegovina   9.3   6.6   3.0   3.0
# 15                       Brazil  11.4   7.1   5.0   5.4
# 16                     Bulgaria   8.6   7.9   7.4   5.9
# 24                        Chile   3.0   3.0   3.0   3.0
# 25                        China  13.3   7.8   3.0   3.0
# 26                     Colombia  10.9  11.2   8.6   7.6
# 29                   Costa Rica   7.0   3.0   3.0   5.3
# 31                      Croatia   3.0   3.0   3.0   3.0
# 34           Dominican Republic  15.0  13.9   9.8   8.8
# 37                  El Salvador  14.7  12.1  10.4   8.4
# 40                      Estonia   3.0   3.0   3.0   3.0
# 43                         Fiji   9.5   8.5   9.3   9.2
# 46                      Georgia  12.3   7.8   6.1   5.7
# 54                      Hungary   5.5   3.0   3.0   3.0
# 57   Iran (Islamic Republic of)  13.7   8.8   7.4   6.5
# 59                      Jamaica   8.6   8.1   8.8   7.0
# 61                   Kazakhstan  11.2  11.6   5.8   5.9
# 64                       Kuwait   3.0   3.0   3.0   3.0
# 65                   Kyrgyzstan  18.0  13.6   9.4   7.8
# 67                       Latvia   5.6   3.0   3.0   3.0
# 72                    Lithuania   5.4   3.0   3.0   3.0
# 80                       Mexico  10.2   8.5   7.0   8.1
# 81            Moldova (Rep. of)  18.7  20.3   6.8   6.9
# 82                     Mongolia  30.0  21.8   9.2   5.7
# 84                      Morocco  15.8  12.4   9.6   9.2
# 92              North Macedonia   7.5   7.2   3.0   3.0
# 95                       Panama  18.6  14.0   9.4   8.1
# 97                     Paraguay  11.6  11.4   8.1   8.0
# 98                         Peru  20.6  15.0   7.6   7.6
# 101                     Romania   7.9   5.8   5.1   3.0
# 102          Russian Federation  10.1   7.1   6.7   6.4
# 104                Saudi Arabia  11.0  12.2   7.4   6.7
# 108                    Slovakia   7.0   5.9   5.7   3.0
# 122           Trinidad & Tobago  11.0  10.7   8.8   9.0
# 123                     Tunisia  10.3   7.6   6.7   6.1
# 124                     Türkiye  10.1   5.8   3.0   3.0
# 125                Turkmenistan  20.4  14.6  10.6   9.5
# 127                     Ukraine  13.0   7.2   7.2   7.5
# 128        United Arab Emirates   6.2   6.5   5.9   5.3
# 129                     Uruguay   7.4   6.5   3.0   3.0
# 130                  Uzbekistan  24.2  15.4   8.3   5.6

# %%
High_Countries = df_GHI.where (df_GHI["2022"] > 18.2)
High_Countries = High_Countries.dropna()
High_Countries
# Out:
#                         Country  2000  2007  2014  2022
# 0                   Afghanistan  50.3  38.7  30.6  29.9
# 3                        Angola  64.9  44.7  26.2  25.9
# 8                    Bangladesh  33.9  31.3  26.3  19.6
# 10                        Benin  33.8  26.9  23.2  21.7
# 14                     Botswana  27.7  25.8  20.5  20.0
# 17                 Burkina Faso  44.9  34.5  26.5  24.5
# 21                     Cameroon  35.8  29.9  21.4  18.9
# 22     Central African Republic  48.8  46.8  44.6  44.0
# 23                         Chad  50.7  49.0  40.7  37.2
# 27                      Comoros  39.5  31.7  29.1  26.9
# 28          Congo (Republic of)  34.7  33.7  25.3  28.1
# 32       Dem. Rep. of the Congo  48.0  43.2  38.7  37.8
# 33                     Djibouti  44.3  35.8  27.4  21.5
# 42                     Ethiopia  53.6  42.6  27.4  27.6
# 45                       Gambia  29.0  26.5  22.2  20.7
# 48                    Guatemala  28.4  24.1  21.7  18.8
# 50                Guinea-Bissau  37.7  31.0  30.2  30.8
# 52                        Haiti  40.9  41.7  32.6  32.7
# 55                        India  38.8  36.3  28.2  29.1
# 62                        Kenya  36.6  31.1  21.6  23.5
# 63                  Korea (DPR)  39.5  29.6  27.5  24.9
# 66                      Lao PDR  44.2  31.4  22.5  19.2
# 69                      Lesotho  32.7  29.1  29.3  32.4
# 70                      Liberia  48.2  39.0  34.8  32.4
# 73                   Madagascar  42.5  37.2  37.3  38.7
# 74                       Malawi  43.3  32.5  24.1  20.7
# 77                         Mali  41.7  35.7  26.1  23.2
# 78                   Mauritania  31.8  28.3  26.3  20.7
# 87                      Namibia  25.4  26.8  22.9  18.7
# 88                        Nepal  37.0  30.0  21.2  19.1
# 90                        Niger  52.5  40.2  32.8  32.6
# 91                      Nigeria  40.4  32.1  28.4  27.3
# 94                     Pakistan  36.8  32.1  29.6  26.1
# 96             Papua New Guinea  33.6  29.9  29.0  26.5
# 103                      Rwanda  49.9  35.9  29.5  27.2
# 107                Sierra Leone  57.5  51.1  33.1  31.5
# 109             Solomon Islands  20.1  18.1  22.3  19.4
# 118   Tanzania (United Rep. of)  40.8  30.9  25.5  23.6
# 121                        Togo  39.3  30.2  26.1  22.8
# 131  Venezuela (Boliv. Rep. of)  14.6  10.1   8.1  19.9
# 133                       Yemen  41.3  38.4  41.7  45.1
# 134                      Zambia  53.3  46.0  35.2  29.3

# %%
High_Countries["2022"].count()
# Out:
# 42

# %%
#Let us see the impact of these 4 parameters (Child mortality, Under-nourishment, Child stunting and Child wasting) on the Global Hunger Index (GHI).

df_child_stunting.drop("Country", inplace=True, axis=1)
df_child_wasting.drop("Country", inplace=True, axis=1)
#df_child_stunting.drop("Country", inplace=True, axis=1)
df_child_mortality.drop("Country", inplace=True, axis=1)

# %%
df_global_hunger_index.rename(columns={'2000':'GHI2000','2007': 'GHI2007', '2014':'GHI2014','2022':'GHI2022' }, inplace=True)
#f_global_hunger_index.head()
df_child_undernourished.rename(columns={'2000':'Nouri2000', '2007':'Nouri2007', '2014': 'Nouri2014','2022':'Nouri2022' }, inplace=True)
df_child_wasting.rename(columns={'2000':'wast2000','2007':'wast2007', '2014': 'wast2014','2022':'wast2022' }, inplace=True)
df_child_stunting.rename(columns={'2000':'stunt2000', '2007':'stunt2007', '2014': 'stunt2014','2022':'stunt2022' }, inplace=True)
df_child_mortality.rename(columns={'2000':'Morta2000', '2007':'Morta2007', '2014': 'Morta2014','2022':'Morta2022' }, inplace=True)

# %%
# frames = [df_global_hunger_index, df_child_undernourished, df_child_wasting, df_child_stunting, df_child_mortality]

# df = pd.concat(frames)
df = pd.concat([df_global_hunger_index, df_child_undernourished, df_child_wasting, df_child_stunting, df_child_mortality], axis=1)
df.head()
# Out:
#        Country  GHI2000  GHI2007  GHI2014  GHI2022      Country  Nouri2000  \
# 0  Afghanistan     50.3     38.7     30.6     29.9  Afghanistan       47.8
# 1      Albania     20.7     15.8      9.2      6.2      Albania        4.9
# 2      Algeria     14.5     11.4      8.7      6.9      Algeria        8.0
# 3       Angola     64.9     44.7     26.2     25.9       Angola       67.5
# 4    Argentina      6.6      5.5      5.0      6.8    Argentina        3.0
#
#    Nouri2007  Nouri2014  Nouri2022  ...  wast2014  wast2022  stunt2000  \
# 0       29.8       20.7       29.8  ...       9.5       5.1       50.6
# 1        8.3        5.0        3.9  ...       4.5       1.6       39.2
# 2        5.9        2.9        2.0  ...       4.1       2.7       23.6
# 3       46.1       13.7       20.8  ...       4.9       6.1       46.7
# 4        3.3        2.0        3.7  ...       1.6       2.7       10.5
#
#    stunt2007  stunt2014  stunt2022  Morta2000  Morta2007  Morta2014  Morta2022
# 0       51.1       40.4       38.2       12.9       10.0        7.4        5.8
# 1       25.0       15.2       11.3        2.7        1.7        1.0        1.0
# 2       15.4       11.7        9.8        4.0        3.1        2.5        2.3
# 3       29.2       37.6       29.8       20.4       14.7        9.3        7.1
# 4        8.2        8.3       12.3        2.0        1.6        1.2        0.9
#
# [5 rows x 22 columns]

# %%
df = df.fillna(df.mean())
#df.fillna(value=0, inplace=True)
#df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    136 non-null    object
#  1   GHI2000    136 non-null    float64
#  2   GHI2007    136 non-null    float64
#  3   GHI2014    136 non-null    float64
#  4   GHI2022    136 non-null    float64
#  5   Country    136 non-null    object
#  6   Nouri2000  136 non-null    float64
#  7   Nouri2007  136 non-null    float64
#  8   Nouri2014  136 non-null    float64
#  9   Nouri2022  136 non-null    float64
#  10  wast2000   136 non-null    float64
#  11  wast2007   136 non-null    float64
#  12  wast2014   136 non-null    float64
#  13  wast2022   136 non-null    float64
#  14  stunt2000  136 non-null    float64
#  15  stunt2007  136 non-null    float64
#  16  stunt2014  136 non-null    float64
#  17  stunt2022  136 non-null    float64
#  18  Morta2000  136 non-null    float64
#  19  Morta2007  136 non-null    float64
#  20  Morta2014  136 non-null    float64
#  21  Morta2022  136 non-null    float64
# dtypes: float64(20), object(2)
# memory usage: 23.5+ KB

# %%
df.corr()
# Out:
#             GHI2000   GHI2007   GHI2014   GHI2022  Nouri2000  Nouri2007  \
# GHI2000    1.000000  0.944637  0.885201  0.845170   0.850373   0.798193
# GHI2007    0.944637  1.000000  0.947987  0.910252   0.843512   0.849286
# GHI2014    0.885201  0.947987  1.000000  0.975957   0.742151   0.776683
# GHI2022    0.845170  0.910252  0.975957  1.000000   0.715811   0.751060
# Nouri2000  0.850373  0.843512  0.742151  0.715811   1.000000   0.925127
# Nouri2007  0.798193  0.849286  0.776683  0.751060   0.925127   1.000000
# Nouri2014  0.691704  0.762196  0.834867  0.838418   0.715905   0.835419
# Nouri2022  0.676769  0.742730  0.820469  0.875887   0.681345   0.779693
# wast2000   0.637679  0.619019  0.624062  0.584009   0.385838   0.344965
# wast2007   0.559703  0.661155  0.637369  0.597103   0.385500   0.359693
# wast2014   0.497941  0.553597  0.622675  0.579321   0.290386   0.278273
# wast2022   0.446211  0.493907  0.555539  0.553005   0.264700   0.243763
# stunt2000  0.808306  0.789556  0.768745  0.726096   0.633037   0.606965
# stunt2007  0.815176  0.849700  0.827129  0.788523   0.669188   0.640547
# stunt2014  0.786880  0.822045  0.848443  0.817992   0.641127   0.619392
# stunt2022  0.743816  0.787158  0.833808  0.836975   0.601279   0.583896
# Morta2000  0.820270  0.808692  0.765256  0.738839   0.627919   0.600514
# Morta2007  0.776009  0.787748  0.763157  0.741943   0.577149   0.550259
# Morta2014  0.748533  0.774806  0.770243  0.752110   0.555133   0.539038
# Morta2022  0.720376  0.751568  0.759498  0.748160   0.528974   0.519846
#
#            Nouri2014  Nouri2022  wast2000  wast2007  wast2014  wast2022  \
# GHI2000     0.691704   0.676769  0.637679  0.559703  0.497941  0.446211
# GHI2007     0.762196   0.742730  0.619019  0.661155  0.553597  0.493907
# GHI2014     0.834867   0.820469  0.624062  0.637369  0.622675  0.555539
# GHI2022     0.838418   0.875887  0.584009  0.597103  0.579321  0.553005
# Nouri2000   0.715905   0.681345  0.385838  0.385500  0.290386  0.264700
# Nouri2007   0.835419   0.779693  0.344965  0.359693  0.278273  0.243763
# Nouri2014   1.000000   0.945901  0.328961  0.321465  0.256611  0.218345
# Nouri2022   0.945901   1.000000  0.320651  0.322292  0.261917  0.223744
# wast2000    0.328961   0.320651  1.000000  0.803290  0.759320  0.734938
# wast2007    0.321465   0.322292  0.803290  1.000000  0.831460  0.786530
# wast2014    0.256611   0.261917  0.759320  0.831460  1.000000  0.919912
# wast2022    0.218345   0.223744  0.734938  0.786530  0.919912  1.000000
# stunt2000   0.583097   0.552065  0.548944  0.501654  0.452948  0.411937
# stunt2007   0.622538   0.595437  0.564181  0.567866  0.486519  0.439401
# stunt2014   0.618548   0.609433  0.564419  0.558459  0.556073  0.515786
# stunt2022   0.624590   0.631820  0.533903  0.528701  0.537176  0.526603
# Morta2000   0.549047   0.565472  0.536336  0.469419  0.365011  0.331026
# Morta2007   0.521781   0.550791  0.546872  0.492131  0.377651  0.340884
# Morta2014   0.533013   0.561647  0.551013  0.510415  0.398450  0.358316
# Morta2022   0.531452   0.561847  0.543769  0.497539  0.397009  0.357113
#
#            stunt2000  stunt2007  stunt2014  stunt2022  Morta2000  Morta2007  \
# GHI2000     0.808306   0.815176   0.786880   0.743816   0.820270   0.776009
# GHI2007     0.789556   0.849700   0.822045   0.787158   0.808692   0.787748
# GHI2014     0.768745   0.827129   0.848443   0.833808   0.765256   0.763157
# GHI2022     0.726096   0.788523   0.817992   0.836975   0.738839   0.741943
# Nouri2000   0.633037   0.669188   0.641127   0.601279   0.627919   0.577149
# Nouri2007   0.606965   0.640547   0.619392   0.583896   0.600514   0.550259
# Nouri2014   0.583097   0.622538   0.618548   0.624590   0.549047   0.521781
# Nouri2022   0.552065   0.595437   0.609433   0.631820   0.565472   0.550791
# wast2000    0.548944   0.564181   0.564419   0.533903   0.536336   0.546872
# wast2007    0.501654   0.567866   0.558459   0.528701   0.469419   0.492131
# wast2014    0.452948   0.486519   0.556073   0.537176   0.365011   0.377651
# wast2022    0.411937   0.439401   0.515786   0.526603   0.331026   0.340884
# stunt2000   1.000000   0.936670   0.919762   0.880797   0.720569   0.667738
# stunt2007   0.936670   1.000000   0.940176   0.917283   0.760601   0.727753
# stunt2014   0.919762   0.940176   1.000000   0.969751   0.733232   0.706751
# stunt2022   0.880797   0.917283   0.969751   1.000000   0.710604   0.691807
# Morta2000   0.720569   0.760601   0.733232   0.710604   1.000000   0.968159
# Morta2007   0.667738   0.727753   0.706751   0.691807   0.968159   1.000000
# Morta2014   0.628017   0.700831   0.681046   0.671304   0.930938   0.982762
# Morta2022   0.606379   0.677608   0.659737   0.658471   0.910675   0.967576
#
#            Morta2014  Morta2022
# GHI2000     0.748533   0.720376
# GHI2007     0.774806   0.751568
# GHI2014     0.770243   0.759498
# GHI2022     0.752110   0.748160
# Nouri2000   0.555133   0.528974
# Nouri2007   0.539038   0.519846
# Nouri2014   0.533013   0.531452
# Nouri2022   0.561647   0.561847
# wast2000    0.551013   0.543769
# wast2007    0.510415   0.497539
# wast2014    0.398450   0.397009
# wast2022    0.358316   0.357113
# stunt2000   0.628017   0.606379
# stunt2007   0.700831   0.677608
# stunt2014   0.681046   0.659737
# stunt2022   0.671304   0.658471
# Morta2000   0.930938   0.910675
# Morta2007   0.982762   0.967576
# Morta2014   1.000000   0.991901
# Morta2022   0.991901   1.000000

# %%
# compute correlation matrix
corr_matrix = df.corr()

# create heatmap of correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Predicting GHI based on the four parameters .

X = df[['Nouri2022', 'wast2022', 'stunt2022', 'Morta2022']]
#y = df['Year'].where(df['Year'] > 2000)
y = df['GHI2022']

# %%
X = X.dropna()
X
# Out:
#      Nouri2022  wast2022  stunt2022  Morta2022
# 0    29.800000       5.1       38.2        5.8
# 1     3.900000       1.6       11.3        1.0
# 2     2.000000       2.7        9.8        2.3
# 3    20.800000       6.1       29.8        7.1
# 4     3.700000       2.7       12.3        0.9
# ..         ...       ...        ...        ...
# 131  22.900000       5.0       22.2        2.4
# 132   5.700000       5.2       19.6        2.1
# 133  41.400000      16.1       55.5        6.0
# 134  30.900000       4.2       34.6        6.1
# 135  12.427273       2.9       23.5        5.4
#
# [136 rows x 4 columns]

# %%
y = y.dropna()
y
# Out:
# 0      29.900000
# 1       6.200000
# 2       6.900000
# 3      25.900000
# 4       6.800000
#          ...
# 131    19.900000
# 132    11.900000
# 133    45.100000
# 134    29.300000
# 135    15.220661
# Name: GHI2022, Length: 136, dtype: float64

# %%
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
predictedGHI = regr.predict([[4, 4, 4, 4]])
predictedGHI
# Out:
# array([8.17344854])

# %%
predictedGHI = regr.predict([[4, 0, 0, 0]])
predictedGHI
# Out:
# array([2.17737244])

# %%
predictedGHI = regr.predict([[0, 4, 0, 0]])
predictedGHI
# Out:
# array([2.8236628])

# %%
predictedGHI = regr.predict([[0, 0, 4, 0]])
predictedGHI
# Out:
# array([0.86897917])

# %%
predictedGHI = regr.predict([[0, 0, 0, 4]])
predictedGHI
# Out:
# array([2.79457585])

# %% [markdown]
# As you can see from the above predictions, Child mortality has more weight than other parameters.

# %% [markdown]
# ### Prediction Model

# %%
X= df_global_hunger_index.mean()
X.array.reshape(1, -1)
X
# Out:
# GHI2000    24.676068
# GHI2007    20.401667
# GHI2014    16.276860
# GHI2022    15.220661
# dtype: float64

# %%
y = [2000,2007,2014,2022]
y = pd.DataFrame (y)
y
# Out:
#       0
# 0  2000
# 1  2007
# 2  2014
# 3  2022

# %%
X.shape, y.shape
# Out:
# ((4,), (4, 1))

# %%
X= X.values.reshape(-1,1)
X
# Out:
# array([[24.67606838],
#        [20.40166667],
#        [16.2768595 ],
#        [15.22066116]])

# %%
X.shape
# Out:
# (4, 1)

# %%
y = y.values
y
# Out:
# array([[2000],
#        [2007],
#        [2014],
#        [2022]], dtype=int64)

# %%
#Linear Regression Model

plt.scatter(X,y)
plt.title("Zero hunger prediction")
plt.xlabel("GHI")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
model = lr.fit(X,y)

# %%
model.intercept_
# Out:
# array([2051.11144851])

# %%
model.coef_
# Out:
# array([[-2.1083285]])

# %%
#Model prediction

y_pred = model.predict(X)
y_pred
# Out:
# array([[1999.08619027],
#        [2008.09803322],
#        [2016.79448172],
#        [2019.0212948 ]])

# %%
Prediction = model.predict([[10]])
Prediction
# Out:
# array([[2030.02816351]])

# %%
Prediction = model.predict([[0]])
Prediction
# Out:
# array([[2051.11144851]])

# %% [markdown]
# The prediction shows that the UN will reach zero hunger in 2051 if the countries maintain their speed between 2000 and 2022.

# %%
plt.scatter(X,y)
plt.plot(X, y_pred, color="orange")
plt.title("Zero hunger prediction")
plt.xlabel("GHI")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
model.score(X,y)
# Out:
# 0.9298124163597172

# %% [markdown]
# Our prediction model has an accuracy of 93%, meaning we have confidence in the predicted year.

# %% [markdown]
# ### Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("GHI2022 scores.csv", encoding= 'unicode_escape')

# %%
df.columns = ['Country', 'GHI_2000', 'GHI_2007', 'GHI_2014', 'GHI_2022', 'Abs_Change_Since_2014', '%_Change_Since_2014']

# %%
df.set_index('Country', inplace=True)

# %%
df.head(4)
# Out:
#              GHI_2000  GHI_2007  GHI_2014  GHI_2022  Abs_Change_Since_2014  \
# Country
# Afghanistan      50.3      38.7      30.6      29.9                   -0.7
# Albania          20.7      15.8       9.2       6.2                   -3.0
# Algeria          14.5      11.4       8.7       6.9                   -1.8
# Angola           64.9      44.7      26.2      25.9                   -0.3
#
#              %_Change_Since_2014
# Country
# Afghanistan                 -2.3
# Albania                    -32.6
# Algeria                    -20.7
# Angola                      -1.1

# %%
# Replace any missing values with 0
df.fillna(0, inplace=True)

# %%
# Convert the GHI index columns to numeric data type
df['GHI_2000'] = pd.to_numeric(df['GHI_2000'])
df['GHI_2007'] = pd.to_numeric(df['GHI_2007'])
df['GHI_2014'] = pd.to_numeric(df['GHI_2014'])
df['GHI_2022'] = pd.to_numeric(df['GHI_2022'])

# %%
# Plot the GHI index for each country
df.plot(kind='line', y=['GHI_2000', 'GHI_2007', 'GHI_2014', 'GHI_2022'])

# Set the plot title and labels
plt.title('GHI Index for Different Countries')
plt.xlabel('Year')
plt.ylabel('GHI Index')

# Display the plot
plt.show()
